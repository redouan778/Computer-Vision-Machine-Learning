# %% [markdown]
# # First Deep Learning Model

# %% [markdown]
# import alle Libaries

# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import make_circles
X, y = make_circles(n_samples=1000,
                    noise=0.1,
                    factor=0.2,
                    random_state=0)

# %% [markdown]
# print de waarde van de variable X

# %%
X
# Out:
# array([[ 0.24265541,  0.0383196 ],
#        [ 0.04433036, -0.05667334],
#        [-0.78677748, -0.75718576],
#        ...,
#        [ 0.0161236 , -0.00548034],
#        [ 0.20624715,  0.09769677],
#        [-0.19186631,  0.08916672]])

# %% [markdown]
# print de grote van de variabe X

# %%
X.shape
# Out:
# (1000, 2)

# %% [markdown]
# Dit visualiseerd de waarde van X

# %%
plt.figure(figsize=(5, 5))
plt.plot(X[y==0, 0], X[y==0, 1], 'ob', alpha=0.5)
plt.plot(X[y==1, 0], X[y==1, 1], 'xr', alpha=0.5)
plt.xlim(-1.5, 1.5)
plt.ylim(-1.5, 1.5)
plt.legend(['0', '1'])
plt.title("Blue circles and Red crosses")
# Out:
# Text(0.5, 1.0, 'Blue circles and Red crosses')

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD

# %% [markdown]
# Maakt een sequential model aan

# %%
model = Sequential()

# %% [markdown]
# Voegt een item aan het model toe met als eigenschap dat alles met elkaar is verbonden is en er zijn 4 nodes.

# %%
model.add(Dense(4, input_shape=(2,), activation='tanh'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(SGD(learning_rate=0.5), 'binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# Dit zorgt ervoor dat de model gaat leren met 20 evoluties

# %%
model.fit(X, y, epochs=20)
# Out:
# Epoch 1/20
# 32/32 [==============================] - 1s 1ms/step - loss: 0.7038 - accuracy: 0.5990
# Epoch 2/20
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6640 - accuracy: 0.6350
# Epoch 3/20
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6067 - accuracy: 0.7330
# Epoch 4/20
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5222 - accuracy: 0.8070
# Epoch 5/20
# 32/32 [==============================] - 0s 2ms/step - loss: 0.4250 - accuracy: 0.8630
# Epoch 6/20
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3354 - accuracy: 0.8910
# Epoch 7/20
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2508 - accuracy: 0.9830
# Epoch 8/20
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1884 - accuracy: 0.9960
# Epoch 9/20
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1467 - accuracy: 1.0000
# Epoch 10/20
# ...

# %%
hticks = np.linspace(-1.5, 1.5, 101)
vticks = np.linspace(-1.5, 1.5, 101)
aa, bb = np.meshgrid(hticks, vticks)
ab = np.c_[aa.ravel(), bb.ravel()]
c = model.predict(ab)
cc = c.reshape(aa.shape)

# %% [markdown]
# Dit tekent wat hier onder staat.

# %%
plt.figure(figsize=(5, 5))
plt.contourf(aa, bb, cc, cmap='bwr', alpha=0.2)
plt.plot(X[y==0, 0], X[y==0, 1], 'ob', alpha=0.5)
plt.plot(X[y==1, 0], X[y==1, 1], 'xr', alpha=0.5)
plt.xlim(-1.5, 1.5)
plt.ylim(-1.5, 1.5)
plt.legend(['0', '1'])
plt.title("Blue circles and Red crosses")
# Out:
# Text(0.5, 1.0, 'Blue circles and Red crosses')
