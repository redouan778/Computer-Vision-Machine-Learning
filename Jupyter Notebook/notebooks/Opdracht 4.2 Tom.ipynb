# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/stores.csv')

# %% [markdown]
# Kolomen in de dataframe

# %%
for c in df.columns:
    print(c)
# Out:
# Store ID
# Store_Area
# Items_Available
# Daily_Customer_Count
# Store_Sales

# %% [markdown]
# Gemiddelde opslag ruimte

# %%
df['Store_Area'].mean()
# Out:
# 1485.4095982142858

# %% [markdown]
# Top 5 grootste winkels

# %%
df.sort_values('Store_Area', ascending=False).head()
# Out:
#      Store ID   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 466        467        2229             2667                   660        87410
# 540        541        2214             2647                   740        65900
# 91          92        2169             2617                   600        67080
# 849        850        2067             2492                   790        70230
# 398        399        2063             2493                   810        51480

# %% [markdown]
# Grootste winkel

# %%
df["Store_Area"].max()
# Out:
# 2229

# %% [markdown]
# Kleinste winkel

# %%
df["Store_Area"].min()
# Out:
# 775

# %% [markdown]
# Gemiddelde winkel groote

# %%
df["Store_Area"].median()
# Out:
# 1477.0

# %% [markdown]
# Winkel met het meeste aantal producten verkocht

# %%
df.iloc[df["Store_Sales"].idxmax()]
# Out:
# Store ID                   650
# Store_Area                1989
# Items_Available           2414
# Daily_Customer_Count       860
# Store_Sales             116320
# Name: 649, dtype: int64

# %% [markdown]
# # Grafieken

# %% [markdown]
# Colleratie tussen beschikbare items en opslag ruimte

# %%
df.plot(kind='scatter',
        x='Store_Area',
        y='Items_Available')
# Out:
# <AxesSubplot:xlabel='Store_Area', ylabel='Items_Available'>

# %% [markdown]
# Colleratie tussen de grote van de winkel en het dagelijkse aantal bezoekers

# %%
df.plot(kind='scatter',
        x='Store_Area',
        y='Daily_Customer_Count')
# Out:
# <AxesSubplot:xlabel='Store_Area', ylabel='Daily_Customer_Count'>

# %% [markdown]
# Colleratie tussen het dagelijkse aantal bezoekers en het aantal verkochte producten

# %%
df.plot(kind='scatter',
        x='Daily_Customer_Count',
        y='Store_Sales')
# Out:
# <AxesSubplot:xlabel='Daily_Customer_Count', ylabel='Store_Sales'>
